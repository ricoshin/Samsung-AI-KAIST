# %% [markdown]
# # <div style="text-align: center"> CNN Architectures </div>
# #### <div style="text-align: right"> 2019.09.19 Thursday </div>
# #### <div style="text-align: right"> Prof. Changho Suh, TA Jaewoong Cho, Junhyung Ahn</div>

# %% [markdown]
# **실습목표**
# - 수업시간에 배운 AlexNet, ResNet 생성
# - CIFAR10 Data 불러오기, 데이터 확인
# - Validation 및 Early stopping 개념 이해
# - AlexNet 과 ResNet에서 CIFAR10 training
# - 성능비교

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras as keras
import numpy as np

import os
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.datasets import cifar10, cifar100
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.datasets.cifar import load_batch
from tensorflow.python.keras.utils.data_utils import get_file
from tensorflow.python.util.tf_export import keras_export
from tensorflow.keras.models import load_model

# %% [markdown]
# ## 1) Functions

# %%
def get_smooth_batch_losses(array):
    smoothing_alpha = 0.95
    output = []
    value = 0
    for i in range(len(array)):
        value = smoothing_alpha * value + (1 - smoothing_alpha) * array[i]
        output.append(value / (1 - smoothing_alpha**(i+1)))
    return output

# %%
def plot(cnn_batch_stats):
    plt.figure(figsize = (15,15))
    
    plt.subplot(2,2,1)
    plt.ylabel("Loss", fontsize=15)
    plt.xlabel("Training Steps", fontsize=15)
    plt.ylim([0,2])
    plt.plot(get_smooth_batch_losses(cnn_batch_stats.batch_losses))

    plt.subplot(2,2,2)
    plt.ylabel("Train Accuracy", fontsize=15)
    plt.xlabel("Training Steps", fontsize=15)
    plt.ylim([0,1])
    plt.plot(get_smooth_batch_losses(cnn_batch_stats.batch_acc))

    plt.subplot(2,2,3)
    plt.ylabel("Loss", fontsize=15)
    plt.xlabel("Epochs" , fontsize=15)
    plt.ylim([0,3])
    plt.plot(cnn_batch_stats.epoch_train_loss, label = 'train loss per epoch')
    plt.plot(cnn_batch_stats.epoch_val_loss, label = 'validation loss per epoch')
    plt.legend()
    
    plt.subplot(2,2,4)
    plt.ylabel("Accuracy", fontsize=15)
    plt.xlabel("Epochs", fontsize=15)
    plt.ylim([0,1])
    plt.plot(cnn_batch_stats.epoch_train_acc, label = 'train accuracy per epoch')
    plt.plot(cnn_batch_stats.epoch_val_acc, label = 'validation accuracy per epoch')
    plt.legend()

# %%
# For logging
class CollectBatchStats(tf.keras.callbacks.Callback):
    def __init__(self):
        self.batch_losses = []
        self.batch_acc = []
        self.epoch_train_loss = []
        self.epoch_train_acc = []
        self.epoch_val_loss = []
        self.epoch_val_acc = []

    def on_batch_end(self, batch, logs=None):
        self.batch_losses.append(logs['loss'])
        self.batch_acc.append(logs['acc'])

    def on_epoch_end(self, epoch, logs=None):
        self.epoch_train_loss.append(logs['loss'])
        self.epoch_train_acc.append(logs['acc'])
        self.epoch_val_loss.append(logs['val_loss'])
        self.epoch_val_acc.append(logs['val_acc'])

# %%
def scheduler(epoch, lr):
    if epoch == 30 or epoch ==60 : 
        lr = lr  * 0.1
    else:
        lr = lr
    return lr

# %% [markdown]
# ## 2) Models

# %% [markdown]
# ### 2-1) AlexNet

# %%
# AleXNet without Batch normalization, Dropout layer  
alexnet_model = tf.keras.models.Sequential()

#1. First Layer (Convolutional Layer)
alexnet_model.add(tf.keras.layers.Conv2D(filters=48, input_shape=(32,32,3), kernel_size=(3,3), 
                                         strides= (1,1), padding='same'))
alexnet_model.add(tf.keras.layers.Activation('relu'))
alexnet_model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2),padding = 'valid'))

#2. Second Layer (Convolutional Layer)
alexnet_model.add(tf.keras.layers.Conv2D(filters=96, kernel_size=(3,3), strides=(1,1), padding='same'))
alexnet_model.add(tf.keras.layers.Activation('relu'))
alexnet_model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2),padding = 'valid'))

#3. Third Layer (Convolutional Layer)
alexnet_model.add(tf.keras.layers.Conv2D(filters=192, kernel_size=(3,3), strides=(1,1), padding='same'))
alexnet_model.add(tf.keras.layers.Activation('relu'))

#4. Fourth Layer (Convolutional Layer)
alexnet_model.add(tf.keras.layers.Conv2D(filters=192, kernel_size=(3,3), strides=(1,1), padding='same'))
alexnet_model.add(tf.keras.layers.Activation('relu'))

#5. Fifth Layer (Convolutional Layer)
alexnet_model.add(tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
alexnet_model.add(tf.keras.layers.Activation('relu'))
alexnet_model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2),padding = 'valid'))

#6. Sixth Layer (Fully Connected Layer)
alexnet_model.add(tf.keras.layers.Flatten())
alexnet_model.add(tf.keras.layers.Dense(512))
alexnet_model.add(tf.keras.layers.Activation('relu'))

#7. Seventh Layer (Fully Connected Layer)
alexnet_model.add(tf.keras.layers.Dense(256))
alexnet_model.add(tf.keras.layers.Activation('relu'))

#8. Eighth Layer (Fully Connected Layer)
alexnet_model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

alexnet_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 48)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 16, 96)        41568
# _________________________________________________________________
# activation_8 (Activation)    (None, 16, 16, 96)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 96)          0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 8, 8, 192)         166080
# _________________________________________________________________
# activation_9 (Activation)    (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 8, 8, 192)         331968
# _________________________________________________________________
# activation_10 (Activation)   (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 8, 8, 256)         442624
# _________________________________________________________________
# activation_11 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               2097664
# _________________________________________________________________
# activation_12 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_13 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 3,215,146
# Trainable params: 3,215,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 2-2) ResNet

# %%
#ResNet
input = keras.layers.Input(shape=(32, 32, 3))
x = keras.layers.Conv2D(32, kernel_size=3, padding='same', strides=(1, 1))(input)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.ReLU()(x)
x = keras.layers.Conv2D(32, kernel_size=3, padding='same', strides=(1, 1))(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.ReLU()(x)
x = keras.layers.MaxPool2D(2)(x)
x = keras.layers.Conv2D(64, kernel_size=3, padding='same', strides=(1, 1))(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.ReLU()(x)
skip = x
x = keras.layers.Conv2D(64, kernel_size=3, padding='same', strides=(1, 1))(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.ReLU()(x)
x = keras.layers.Conv2D(64, kernel_size=3, padding='same', strides=(1, 1))(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Add()([x, skip])
x = keras.layers.ReLU()(x)
x = keras.layers.MaxPool2D(2)(x)
x = keras.layers.Conv2D(128, kernel_size=3, padding='same', strides=(1, 1))(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.ReLU()(x)
skip = x
x = keras.layers.Conv2D(128, kernel_size=3, padding='same', strides=(1, 1))(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.ReLU()(x)
x = keras.layers.Conv2D(128, kernel_size=3, padding='same', strides=(1, 1))(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Add()([x, skip])
x = keras.layers.ReLU()(x)
x = keras.layers.AveragePooling2D(pool_size=(8, 8))(x)
x = keras.layers.Flatten()(x)

# Fully-connected layer
output = keras.layers.Dense(10, activation=tf.nn.softmax)(x)
resnet = keras.models.Model(input, output)

resnet.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 32)   896         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 32, 32, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 32)   9248        re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 32)   128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 32, 32, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 32)   0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   18496       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 16, 16, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   36928       re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 64)   36928       re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 64)   0           batch_normalization_12[0][0]
#                                                                  re_lu_10[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 16, 16, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 64)     0           re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 128)    73856       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 128)    512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 128)    147584      re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 128)    512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    147584      re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 128)    0           batch_normalization_15[0][0]
#                                                                  re_lu_13[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 8, 8, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 128)    0           re_lu_15[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 128)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           1290        flatten_2[0][0]
# ==================================================================================================
# Total params: 475,370
# Trainable params: 474,090
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
models = {'alexnet': alexnet_model , 'resnet': resnet}

# %% [markdown]
# ## 3) Dataset

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 1/5, stratify=y_train)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (40000, 32, 32, 3)
# 40000 train samples
# 10000 test samples

# %%
num_classes = 10
class_names = ['airplane','automobile',
                       'bird','cat',
                       'deer','dog',
                       'frog','horse',
                       'ship','truck']

fig = plt.figure(figsize=(8,3))

for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(y_train[:]==i)[0]
    features_idx = x_train[idx]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# ## 4) Training

# %% [markdown]
# ### 4-1) AlexNet training

# %%
#Experiment setting
LRSchedule_flag = False #True or False
learning_rate = 0.001
momentum=0.9
batch_size = 128
epochs = 200

# %%
model_name = 'alexnet'
cnn_model = models[model_name]

# Compile CNN model
cnn_model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=momentum),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

#model save folder path
model_save_folder_path = './model/'
if not os.path.exists(model_save_folder_path):
    os.mkdir(model_save_folder_path)

model_save_folder_path = model_save_folder_path+model_name
if not os.path.exists(model_save_folder_path):
    os.mkdir(model_save_folder_path)
    
model_path = model_save_folder_path+'/best_model.hdf5'

#collect callback
cnn_batch_stats = CollectBatchStats()
#checkpoint callback
cb_checkpoint = ModelCheckpoint(filepath=model_path, 
                                monitor='val_acc',
                                verbose=1, 
                                save_best_only=True)
#early stopping callback
cb_early_stopping = EarlyStopping(monitor='val_acc', patience=20)
#learning rate schedule callback
cb_learning_rate_schedule = LearningRateScheduler(scheduler)

if LRSchedule_flag:
    callbacks = [cnn_batch_stats, cb_checkpoint, cb_learning_rate_schedule]
else:
    callbacks = [cnn_batch_stats, cb_checkpoint, cb_early_stopping]
    
# Train CNN model
cnn_model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              callbacks=callbacks,
              validation_data=(x_val, y_val))
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/200
# 39424/40000 [============================>.] - ETA: 0s - loss: 2.2887 - acc: 0.1384
# Epoch 00001: val_acc improved from -inf to 0.15190, saving model to ./model/alexnet/best_model.hdf5
# 40000/40000 [==============================] - 5s 124us/sample - loss: 2.2883 - acc: 0.1389 - val_loss: 2.2597 - val_acc: 0.1519
# Epoch 2/200
# 39808/40000 [============================>.] - ETA: 0s - loss: 2.1214 - acc: 0.2328
# Epoch 00002: val_acc improved from 0.15190 to 0.25210, saving model to ./model/alexnet/best_model.hdf5
# 40000/40000 [==============================] - 4s
val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 97us/sample - loss: 3.5406e-04 - acc: 1.0000 - val_loss: 2.7079 - val_acc: 0.6875
# Epoch 88/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 3.4317e-04 - acc: 1.0000
# Epoch 00088: val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 95us/sample - loss: 3.4300e-04 - acc: 1.0000 - val_loss: 2.7153 - val_acc: 0.6874
# Epoch 89/200
# 39808/40000 [============================>.] - ETA: 0s - loss: 3.3436e-04 - acc: 1.0000
# Epoch 00089: val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 96us/sample - loss: 3.3402e-04 - acc: 1.0000 - val_loss: 2.7240 - val_acc: 0.6874
# Epoch 90/200
# 39808/40000 [============================>.] - ETA: 0s - loss: 3.2395e-04 - acc: 1.0000
# Epoch 00090: val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 98us/sample - loss: 3.2367e-04 - acc: 1.0000 - val_loss: 2.7314 - val_acc: 0.6876
# Epoch 91/200
# 39808/40000 [============================>.] - ETA: 0s - loss: 3.1639e-04 - acc: 1.0000
# Epoch 00091: val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 95us/sample - loss: 3.1621e-04 - acc: 1.0000 - val_loss: 2.7391 - val_acc: 0.6875
# Epoch 92/200
# 39424/40000 [============================>.] - ETA: 0s - loss: 3.0842e-04 - acc: 1.0000
# Epoch 00092: val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 94us/sample - loss: 3.0812e-04 - acc: 1.0000 - val_loss: 2.7495 - val_acc: 0.6870
# Epoch 93/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 3.0143e-04 - acc: 1.0000
# Epoch 00093: val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 95us/sample - loss: 3.0238e-04 - acc: 1.0000 - val_loss: 2.7547 - val_acc: 0.6868
# Epoch 94/200
# 39808/40000 [============================>.] - ETA: 0s - loss: 2.9398e-04 - acc: 1.0000
# Epoch 00094: val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 97us/sample - loss: 2.9344e-04 - acc: 1.0000 - val_loss: 2.7601 - val_acc: 0.6880
# Epoch 95/200
# 39808/40000 [============================>.] - ETA: 0s - loss: 2.8686e-04 - acc: 1.0000
# Epoch 00095: val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 96us/sample - loss: 2.8637e-04 - acc: 1.0000 - val_loss: 2.7701 - val_acc: 0.6884
# Epoch 96/200
# 39808/40000 [============================>.] - ETA: 0s - loss: 2.7835e-04 - acc: 1.0000
# Epoch 00096: val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 97us/sample - loss: 2.7980e-04 - acc: 1.0000 - val_loss: 2.7790 - val_acc: 0.6864
# Epoch 97/200
# 39808/40000 [============================>.] - ETA: 0s - loss: 2.7488e-04 - acc: 1.0000
# Epoch 00097: val_acc did not improve from 0.68860
# 40000/40000 [==============================] - 4s 95us/sample - loss: 2.7521e-04 - acc: 1.0000 - val_loss: 2.7844 - val_acc: 0.6874

# %%
plot(cnn_batch_stats)

# %%
test_loss, test_acc = cnn_model.evaluate(x_test, y_test)
print('Test acc = ', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 99us/sample - loss: 2.7511 - acc: 0.6791
# Test acc =  0.6791

# %%
saved_model = load_model(model_path)
test_loss, test_acc = saved_model.evaluate(x_test, y_test)
print('Test acc = ', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 113us/sample - loss: 2.5732 - acc: 0.6795
# Test acc =  0.6795

# %% [markdown]
# ### 4-2) ResNet training

# %%
#Experiment Setting
LRSchedule_flag = False #True or False
learning_rate = 0.01
momentum = 0.9
batch_size = 128
epochs = 200

# %%
model_name = 'resnet'
cnn_model = models[model_name]

# Compile CNN model
cnn_model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=momentum),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

#model save folder path
model_save_folder_path = './model/'
if not os.path.exists(model_save_folder_path):
    os.mkdir(model_save_folder_path)

model_save_folder_path = model_save_folder_path+model_name
if not os.path.exists(model_save_folder_path):
    os.mkdir(model_save_folder_path)
    
model_path = model_save_folder_path+'/best_model.hdf5'

#collect callback
cnn_batch_stats = CollectBatchStats()
#checkpoint callback
cb_checkpoint = ModelCheckpoint(filepath=model_path, 
                                monitor='val_acc',
                                verbose=1, 
                                save_best_only=True)
#early stopping callback
cb_early_stopping = EarlyStopping(monitor='val_acc', patience=20)
#learning rate schedule callback
cb_learning_rate_schedule = LearningRateScheduler(scheduler)

if LRSchedule_flag:
    callbacks = [cnn_batch_stats, cb_checkpoint, cb_learning_rate_schedule]
else:
    callbacks = [cnn_batch_stats, cb_checkpoint, cb_early_stopping]
    
# Train CNN model
cnn_model.fit(x_train, y_train,
              batch_size=batch_size,epochs=epochs,
              callbacks=callbacks,
              validation_data=(x_val, y_val),)
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 1.3629 - acc: 0.5074
# Epoch 00001: val_acc improved from -inf to 0.33230, saving model to ./model/resnet/best_model.hdf5
# 40000/40000 [==============================] - 6s 158us/sample - loss: 1.3598 - acc: 0.5088 - val_loss: 1.9999 - val_acc: 0.3323
# Epoch 2/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 0.9387 - acc: 0.6678
# Epoch 00002: val_acc improved from 0.33230 to 0.56710, saving model to ./model/resnet/best_model.hdf5
# 40000/40000 [==============================] - 5s 132us/sample - loss: 0.9382 - acc: 0.6682 - val_loss: 1.2494 - val_acc: 0.5671
# Epoch 3/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 0.7677 - acc: 0.7310
# Epoch 00003: val_acc improved from 0.56710 to 0.65980, saving model to ./model/resnet/best_model.hdf5
# 40000/40000 [==============================] - 5s 133us/sample - loss: 0.7675 - acc: 0.7310 - val_loss: 1.0187 - val_acc: 0.6598
# Epoch 4/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 0.6478 - acc: 0.7744
# Epoch 00004: val_acc improved from 0.65980 to 0.66580, saving model to ./model/resnet/best_model.hdf5
# 40000/40000 [==============================] - 5s 134us/sample - loss: 0.6478 - acc: 0.7745 - val_loss: 0.9904 - val_acc: 0.6658
# Epoch 5/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 0.5630 - acc: 0.8037
# Epoch 00005: val_acc did not improve from 0.66580
# 40000/40000 [==============================] - 5s 132us/sample - loss: 0.5628 - acc: 0.8038 - val_loss: 1.3361 - val_acc: 0.5990
# Epoch 6/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 0.4937 - acc: 0.8285
# Epoch 00006: val_acc improved from 0.66580 to 0.66820, saving model to ./model/resnet/best_model.hdf5
# 40000/40000 [==============================] - 5s 134us/sample - loss: 0.4934 - acc: 0.8286 - val_loss: 0.9986 - val_acc: 0.6682
# Epoch 7/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 0.4310 - acc: 0.8499
# Epoch 00007: val_acc did not improve from 0.66820
# 40000/40000 [==============================] - 5s 132us/sample - loss: 0.4314 - acc: 0.8498 - val_loss: 1.2561 - val_acc: 0.6193
# Epoch 8/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 0.3907 - acc: 0.8636
# Epoch 00008: val_acc improved from 0.66820 to 0.77160, saving model to ./model/resnet/best_model.hdf5
# 40000/40000 [==============================] - 5s 134us/sample - loss: 0.3907 - acc: 0.8636 - val_loss: 0.7015 - val_acc: 0.7716
# Epoch 9/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 0.3337 - acc: 0.8852
# Epoch 00009: val_acc did not improve from 0.77160
# 40000/40000 [==============================] - 5s 133us/sample - loss: 0.3332 - acc: 0.8855 - val_loss: 0.9422 - val_acc: 0.7072
# Epoch 10/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 0.2832 - acc: 0.9023
# Epoch 00010: val_acc did not improve from 0.77160
# 40000/40000 [==============================] - 5s 133us/sample - loss: 0.2831 - acc: 0.9023 - val_loss: 0.7933 - val_acc: 0.7473
# Epoch 11/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 0.2485 - acc: 0.9150
# Epoch 00011: val_acc did not improve from 0.77160
# 40000/40000 [==============================] - 5s 133us/sample - loss: 0.2488 - acc: 0.9148 - val_loss: 1.0288 - val_acc: 0.7222
# Epoch 12/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 0.2109 - acc: 0.9268
# Epoch 00012: val_acc did not improve from 0.77160
# 40000/40000 [==============================] - 5s 133us/sample - loss: 0.2109 - acc: 0.9268 - val_loss: 1.2232 - val_acc: 0.6916
# Epoch 13/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 0.1700 - acc: 0.9431
# Epoch 00013: val_acc did not improve from 0.77160
# 40000/40000 [==============================] - 5s 133us/sample - loss: 0
200
# 39552/40000 [============================>.] - ETA: 0s - loss: 6.0953e-04 - acc: 1.0000
# Epoch 00044: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 131us/sample - loss: 6.0930e-04 - acc: 1.0000 - val_loss: 0.7939 - val_acc: 0.8352
# Epoch 45/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 6.0264e-04 - acc: 1.0000
# Epoch 00045: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 134us/sample - loss: 6.0720e-04 - acc: 1.0000 - val_loss: 0.7936 - val_acc: 0.8349
# Epoch 46/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 5.7083e-04 - acc: 1.0000
# Epoch 00046: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 133us/sample - loss: 5.7279e-04 - acc: 1.0000 - val_loss: 0.7943 - val_acc: 0.8358
# Epoch 47/200
# 39808/40000 [============================>.] - ETA: 0s - loss: 5.9292e-04 - acc: 1.0000
# Epoch 00047: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 131us/sample - loss: 5.9455e-04 - acc: 1.0000 - val_loss: 0.8025 - val_acc: 0.8359
# Epoch 48/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 5.6792e-04 - acc: 1.0000
# Epoch 00048: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 133us/sample - loss: 5.6759e-04 - acc: 1.0000 - val_loss: 0.8019 - val_acc: 0.8343
# Epoch 49/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 5.2891e-04 - acc: 1.0000
# Epoch 00049: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 133us/sample - loss: 5.2855e-04 - acc: 1.0000 - val_loss: 0.8103 - val_acc: 0.8342
# Epoch 50/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 5.3672e-04 - acc: 1.0000
# Epoch 00050: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 134us/sample - loss: 5.3878e-04 - acc: 1.0000 - val_loss: 0.8086 - val_acc: 0.8355
# Epoch 51/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 5.2122e-04 - acc: 1.0000
# Epoch 00051: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 134us/sample - loss: 5.2268e-04 - acc: 1.0000 - val_loss: 0.8093 - val_acc: 0.8355
# Epoch 52/200
# 39808/40000 [============================>.] - ETA: 0s - loss: 5.0415e-04 - acc: 1.0000
# Epoch 00052: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 133us/sample - loss: 5.0558e-04 - acc: 1.0000 - val_loss: 0.8095 - val_acc: 0.8342
# Epoch 53/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 4.6860e-04 - acc: 1.0000
# Epoch 00053: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 132us/sample - loss: 4.7027e-04 - acc: 1.0000 - val_loss: 0.8137 - val_acc: 0.8346
# Epoch 54/200
# 39936/40000 [============================>.] - ETA: 0s - loss: 4.7237e-04 - acc: 1.0000
# Epoch 00054: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 134us/sample - loss: 4.7368e-04 - acc: 1.0000 - val_loss: 0.8073 - val_acc: 0.8360
# Epoch 55/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 4.6726e-04 - acc: 1.0000
# Epoch 00055: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 130us/sample - loss: 4.6673e-04 - acc: 1.0000 - val_loss: 0.8140 - val_acc: 0.8353
# Epoch 56/200
# 39552/40000 [============================>.] - ETA: 0s - loss: 4.7801e-04 - acc: 1.0000
# Epoch 00056: val_acc did not improve from 0.83660
# 40000/40000 [==============================] - 5s 134us/sample - loss: 4.7837e-04 - acc: 1.0000 - val_loss: 0.8159 - val_acc: 0.8354

# %%
plot(cnn_batch_stats)

# %%
test_loss, test_acc = cnn_model.evaluate(x_test, y_test)
print('Test acc = ', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 125us/sample - loss: 0.8100 - acc: 0.8340
# Test acc =  0.834

# %%
saved_model = load_model(model_path)
test_loss, test_acc = saved_model.evaluate(x_test, y_test)
print('Test acc = ', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 138us/sample - loss: 0.7656 - acc: 0.8366
# Test acc =  0.8366
